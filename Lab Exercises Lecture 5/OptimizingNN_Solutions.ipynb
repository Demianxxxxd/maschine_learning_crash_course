# %% [markdown]
# # Optimizing Neural Network Hyperparameters
#
# We will consider again an Image Recognition problem with the MNIST dataset (Images of 28 x 28 pixels).
# The MNIST dataset has a training set of 60,000 images and a test set of 10,000 images.
# The digits have been sized-normalized and centered in a fixed-size image.
# It is a good database for people who want to try learning techniques and pattern recognition methods on real-world data while spending minimal efforts on preprocessing and formatting.
#
# In this Notebook you will follow four different approaches to tune the hyperparameters:
# - "Trial and Error" approach
# - "Grid Search" Hyperparameter optimization with Scikit-Learn wrapper
# - "Random Search" Hyperparameter optimization with Scikit-Learn wrapper
# - Bayesian Optimization using Hyperopt

# %% [markdown]
# ### Data Preparation

# %%
from keras.datasets import mnist
import numpy as np

(train_images, train_labels), (test_images, test_labels) = mnist.load_data() # train_x, train_y, test_x, test_y
# x values are the 28x28 pixels
# y values are the labels, the digit that is being represented in the image. We have 10 labels. Digits from 0 to 9.

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
# We need to encode the categorical labels in one-hot format

from tensorflow.keras.utils import to_categorical

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# We split the training set into training and validation set
# 30% validation, 70% training

split_size = int(train_images.shape[0]*0.7)

train_images, val_images = train_images[:split_size], train_images[split_size:]
train_labels, val_labels = train_labels[:split_size], train_labels[split_size:]

# %%
# Fix random seed for reproducibility
seed = 42
np.random.seed(seed)

# %% [markdown]
# ### Building the Model
#
# Build a neural network with 3 layers, input, hidden and output:
# - Dense layer with 50 hidden units and an appropriate activation function;
# - Dense layer with 10 output units and appropriate activation function;
#
# First we define some useful parameters:

# %%
# define vars
input_num_units = 784 # 28x28
hidden_num_units = 50
output_num_units = 10

epochs = 5
batch_size = 128

# %% [markdown]
# **Import Keras packages that you think may need.**

# %%
# Import Keras modules
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers

# %% [markdown]
# **Create the model as described above.**

# %%
# Create a Sequential Model
model = models.Sequential()
model.add(layers.Dense(units=hidden_num_units, activation='relu', input_shape=(input_num_units,)))
model.add(layers.Dense(units=output_num_units, activation='softmax'))

# Print a summary of your model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                39250
#
#  dense_1 (Dense)             (None, 10)                510
#
# =================================================================
# Total params: 39,760
# Trainable params: 39,760
# Non-trainable params: 0
# _________________________________________________________________

# %%
# or Create a functional model
from keras import Input
from keras import Model

inputs = Input(shape=(input_num_units,))
x = layers.Dense(hidden_num_units, activation='relu')(inputs)
outputs = layers.Dense(output_num_units, activation='softmax')(x)
func_model = Model(inputs=inputs, outputs=outputs)

# Print a summary of your model
# Here the input layer is shown in the summary
func_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense_2 (Dense)             (None, 50)                39250
#
#  dense_3 (Dense)             (None, 10)                510
#
# =================================================================
# Total params: 39,760
# Trainable params: 39,760
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Configure the model with an optimizer and an appropriate loss function.**

# %%
# Compile the model with necessary attributes
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# **Train the model (also with the validation set).**

# %%
# Train the model
trained_model = model.fit(train_images, train_labels, epochs=epochs, 
                          batch_size=batch_size, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/5
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x152b4d170> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x152b4d170> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 323/329 [============================>.] - ETA: 0s - loss: 0.5186 - accuracy: 0.8602WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x152dc3d40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x152dc3d40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 329/329 [==============================] - 2s 4ms/step - loss: 0.5159 - accuracy: 0.8605 - val_loss: 0.2889 - val_accuracy: 0.9176
# Epoch 2/5
# 329/329 [==============================] - 1s 3ms/step - loss: 0.2504 - accuracy: 0.9288 - val_loss: 0.2316 - val_accuracy: 0.9343
# Epoch 3/5
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1997 - accuracy: 0.9425 - val_loss: 0.1976 - val_accuracy: 0.9442
# Epoch 4/5
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1666 - accuracy: 0.9537 - val_loss: 0.1754 - val_accuracy: 0.9505
# Epoch 5/5
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1430 - accuracy: 0.9603 - val_loss: 0.1594 - val_accuracy: 0.9549

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# **Test the model: get predictions and evaluate the model.**

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay

pred = np.argmax(model.predict(test_images), axis=-1)
label = np.argmax(test_labels, axis = 1)

confusion = confusion_matrix(label, pred)
print(confusion)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x1546709e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x1546709e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[ 967    0    1    3    1    1    2    2    2    1]
#  [   0 1116    4    0    1    1    4    2    7    0]
#  [   3    3  981    8    5    2    4    7   19    0]
#  [   1    0    9  958    0    8    0    9   17    8]
#  [   1    0    6    0  949    0    2    2    3   19]
#  [   5    1    0   19    6  823   11    3   20    4]
#  [   8    3    1    2    6    9  920    2    7    0]
#  [   0    8   15    6    3    1    0  972    3   20]
#  [   4    3    2    9    6    4    5    9  927    5]
#  [   5    6    1   12   18    2    0   12    5  948]]

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1474 - accuracy: 0.9561

# %%
print('test_acc:', test_acc)
# Out:
# test_acc: 0.9560999870300293

# %% [markdown]
# Let's try to improve it by tuning some Hyperparameters.
#
# ### Hyperparameters Optimization - Trial and Error
#
# Some important parameters to look out while optimizing neural networks are:
# - Type of architecture
# - Number of layers
# - Number of neurons per layer
# - Regularization parameters
# - Learning rate
# - Type of optimization/backpropagation technique
# - Dropout rate
# - Weight sharing

# %% [markdown]
# Now repeat all the previous steps (train, test etc..) but tuning the following parameters:
# 1. Make the model "wide": Increase the number of neurons in the hidden layer;
# 2. Make the model "deep": Increase the number of hidden layers neurons each;
# 3. Dropout to deal with Overfitting;
# 4. Increase Epochs to 50;
# 5. Both "wide" and "deep": more hidden layers, each with more than 50 neurons
#
# After every step, analyse your results and draw some conclusions.

# %% [markdown]
# ### 1. Make the model "wide": increase number of neurons in the hidden layer.

# %% [markdown]
# **Define the new variables.**

# %%
input_num_units = 784
hidden_num_units = 500
output_num_units = 10
epochs = 5
batch_size = 128

# %% [markdown]
# **Build the network.**

# %%
model_1  = models.Sequential()
model_1.add(layers.Dense(units=hidden_num_units, activation='relu', input_shape=(input_num_units,)))
model_1.add(layers.Dense(units=output_num_units, activation='softmax'))

# %% [markdown]
# **Configure the network.**

# %%
model_1.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# **Train the network.**

# %%
trained_model_1 = model_1.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/5
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x15476bb90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x15476bb90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 324/329 [============================>.] - ETA: 0s - loss: 0.3096 - accuracy: 0.9132WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x154da7680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x154da7680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 329/329 [==============================] - 4s 10ms/step - loss: 0.3087 - accuracy: 0.9135 - val_loss: 0.1844 - val_accuracy: 0.9477
# Epoch 2/5
# 329/329 [==============================] - 3s 9ms/step - loss: 0.1329 - accuracy: 0.9614 - val_loss: 0.1324 - val_accuracy: 0.9607
# Epoch 3/5
# 329/329 [==============================] - 3s 10ms/step - loss: 0.0854 - accuracy: 0.9757 - val_loss: 0.1066 - val_accuracy: 0.9691
# Epoch 4/5
# 329/329 [==============================] - 3s 8ms/step - loss: 0.0623 - accuracy: 0.9827 - val_loss: 0.0983 - val_accuracy: 0.9711
# Epoch 5/5
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0447 - accuracy: 0.9875 - val_loss: 0.0973 - val_accuracy: 0.9704

# %% [markdown]
# Considerations: what can you notice from these results? Is your model performing better than before?

# %% [markdown]
# **Results**: the model should perform a lot better than before.

# %% [markdown]
# ### 2. Make the model "deep": Increase the number of hidden layers.

# %% [markdown]
# **Define the new variables.**

# %%
input_num_units = 784
hidden1_num_units = 50
hidden2_num_units = 50
hidden3_num_units = 50
hidden4_num_units = 50
hidden5_num_units = 50
output_num_units = 10

epochs = 5
batch_size = 128

# %% [markdown]
# **Build the network.**

# %%
model_2 = models.Sequential()

model_2.add(layers.Dense(units=hidden1_num_units, input_shape=(input_num_units,), activation='relu'))
model_2.add(layers.Dense(units=hidden2_num_units, activation='relu'))
model_2.add(layers.Dense(units=hidden3_num_units, activation='relu'))
model_2.add(layers.Dense(units=hidden4_num_units, activation='relu'))
model_2.add(layers.Dense(units=hidden5_num_units, activation='relu'))

model_2.add(layers.Dense(units=output_num_units, activation='softmax'))

model_2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 50)                39250
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_8 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_9 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dense_10 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                510
# =================================================================
# Total params: 49,960
# Trainable params: 49,960
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Configure the network.**

# %%
model_2.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# **Train the network.**

# %%
trained_model_2 = model_2.fit(train_images, train_labels, epochs=epochs, 
                              batch_size=batch_size, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/5
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x15a373dd0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x15a373dd0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 322/329 [============================>.] - ETA: 0s - loss: 0.5408 - accuracy: 0.8296WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x15aa42b00> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x15aa42b00> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 329/329 [==============================] - 2s 5ms/step - loss: 0.5350 - accuracy: 0.8316 - val_loss: 0.2358 - val_accuracy: 0.9304
# Epoch 2/5
# 329/329 [==============================] - 2s 5ms/step - loss: 0.1901 - accuracy: 0.9427 - val_loss: 0.1781 - val_accuracy: 0.9471
# Epoch 3/5
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1425 - accuracy: 0.9573 - val_loss: 0.1629 - val_accuracy: 0.9506
# Epoch 4/5
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1103 - accuracy: 0.9664 - val_loss: 0.1438 - val_accuracy: 0.9570
# Epoch 5/5
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0921 - accuracy: 0.9727 - val_loss: 0.1326 - val_accuracy: 0.9623

# %% [markdown]
# Considerations: what can you notice from these results? Is your model performing better than before?

# %% [markdown]
# **Results**: the model is performing slightly better than the orgininal model but worse than the second model. This may be due to a little bit of overfitting. To deal with this, we will use the dropout technique.

# %% [markdown]
# ### 3. Dropout

# %% [markdown]
# <img src="images/dropout.png" width='500'/>
#
# **Define the new variables, remember to define also the dropout_ratio.**

# %%
input_num_units = 784
hidden1_num_units = 50
hidden2_num_units = 50
hidden3_num_units = 50
hidden4_num_units = 50
hidden5_num_units = 50
output_num_units = 10

epochs = 5
batch_size = 128

dropout_ratio = 0.2

# %% [markdown]
# **Build the network.**

# %%
model_3 = models.Sequential()

model_3.add(layers.Dense(units=hidden1_num_units, input_shape=(input_num_units,), activation='relu'))
model_3.add(layers.Dropout(dropout_ratio))
model_3.add(layers.Dense(units=hidden2_num_units, activation='relu'))
model_3.add(layers.Dropout(dropout_ratio))
model_3.add(layers.Dense(units=hidden3_num_units, activation='relu'))
model_3.add(layers.Dropout(dropout_ratio))
model_3.add(layers.Dense(units=hidden4_num_units, activation='relu'))
model_3.add(layers.Dropout(dropout_ratio))
model_3.add(layers.Dense(units=hidden5_num_units, activation='relu'))
model_3.add(layers.Dropout(dropout_ratio))

model_3.add(layers.Dense(output_num_units, activation='softmax'))

model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 50)                39250
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 50)                2550
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                510
# =================================================================
# Total params: 49,960
# Trainable params: 49,960
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Configure the network.**

# %%
model_3.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# **Train the network.**

# %%
trained_model_3 = model_3.fit(train_images, train_labels, epochs=epochs, batch_size=batch_size, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/5
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x154cc68c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x154cc68c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 325/329 [============================>.] - ETA: 0s - loss: 1.0759 - accuracy: 0.6299WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x154d53a70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x154d53a70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 329/329 [==============================] - 3s 6ms/step - loss: 1.0710 - accuracy: 0.6317 - val_loss: 0.3273 - val_accuracy: 0.9090
# Epoch 2/5
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4526 - accuracy: 0.8765 - val_loss: 0.2355 - val_accuracy: 0.9341
# Epoch 3/5
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3519 - accuracy: 0.9063 - val_loss: 0.2156 - val_accuracy: 0.9403
# Epoch 4/5
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3065 - accuracy: 0.9187 - val_loss: 0.1946 - val_accuracy: 0.9468
# Epoch 5/5
# 329/329 [==============================] - 1s 5ms/step - loss: 0.2749 - accuracy: 0.9288 - val_loss: 0.1844 - val_accuracy: 0.9491

# %% [markdown]
# Considerations: what can you notice from these results? Is your model improving?

# %% [markdown]
# **Results**: There seems to be some problems, the model is not improving. One possible reason may be that we are not using enough epochs to train the model. Let's try to increase the number of training epochs.

# %% [markdown]
# ### 4. Increase training Epochs to 50.
#
# This will take a while.

# %% [markdown]
# **Define the new variables.**

# %%
input_num_units = 784
hidden1_num_units = 50
hidden2_num_units = 50
hidden3_num_units = 50
hidden4_num_units = 50
hidden5_num_units = 50
output_num_units = 10

epochs = 50
batch_size = 128

# %% [markdown]
# **Build the network.**

# %%
model_4 = models.Sequential()

model_4.add(layers.Dense(units=hidden1_num_units, input_shape=(input_num_units, ), activation='relu'))
model_4.add(layers.Dropout(0.2))
model_4.add(layers.Dense(units=hidden2_num_units, activation='relu'))
model_4.add(layers.Dropout(0.2))
model_4.add(layers.Dense(units=hidden3_num_units, activation='relu'))
model_4.add(layers.Dropout(0.2))
model_4.add(layers.Dense(units=hidden4_num_units, activation='relu'))
model_4.add(layers.Dropout(0.2))
model_4.add(layers.Dense(units=hidden5_num_units, activation='relu'))
model_4.add(layers.Dropout(0.2))

model_4.add(layers.Dense(units=output_num_units, activation='softmax'))

model_4.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 50)                39250
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_16 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                510
# =================================================================
# Total params: 49,960
# Trainable params: 49,960
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Configure the network.**

# %%
model_4.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# **Train the network.**

# %%
trained_model_4 = model_4.fit(train_images, train_labels, epochs=epochs, 
                              batch_size=batch_size, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/50
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x15567f8c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x15567f8c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 321/329 [============================>.] - ETA: 0s - loss: 1.0227 - accuracy: 0.6568WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1552c3440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1552c3440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 329/329 [==============================] - 3s 6ms/step - loss: 1.0111 - accuracy: 0.6610 - val_loss: 0.3133 - val_accuracy: 0.9077
# Epoch 2/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.4249 - accuracy: 0.8836 - val_loss: 0.2247 - val_accuracy: 0.9373
# Epoch 3/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.3357 - accuracy: 0.9124 - val_loss: 0.2062 - val_accuracy: 0.9443
# Epoch 4/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2935 - accuracy: 0.9226 - val_loss: 0.1807 - val_accuracy: 0.9504
# Epoch 5/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2636 - accuracy: 0.9323 - val_loss: 0.1699 - val_accuracy: 0.9533
# Epoch 6/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2431 - accuracy: 0.9364 - val_loss: 0.1683 - val_accuracy: 0.9533
# Epoch 7/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.2288 - accuracy: 0.9407 - val_loss: 0.1602 - val_accuracy: 0.9575
# Epoch 8/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2120 - accuracy: 0.9439 - val_loss: 0.1611 - val_accuracy: 0.9573
# Epoch 9/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2047 - accuracy: 0.9460 - val_loss: 0.1582 - val_accuracy: 0.9580
# Epoch 10/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1933 - accuracy: 0.9502 - val_loss: 0.1491 - val_accuracy: 0.9616
# Epoch 11/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1903 - accuracy: 0.9509 - val_loss: 0.1586 - val_accuracy: 0.9571
# Epoch 12/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1847 - accuracy: 0.9508 - val_loss: 0.1508 - val_accuracy: 0.9616
# Epoch 13/50
# 329/329 [==============================] - 1s 5ms/step - loss: 0.1771 - accuracy: 0.9535 - val_loss: 0.1391 - val_accuracy: 0.9638: 0s - loss: 0.1776 - ac
# Epoch 14/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1751 - accuracy: 0.9546 - val_loss: 0.1414 - val_accuracy: 0.9631
# Epoch 15/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.1669 - accuracy: 0.9559 - val_loss: 0.1467 - val_accuracy: 0.9623
# Epoch 16/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1659 - accuracy: 0.9569 - val_loss: 0.1476 - val_accuracy: 0.9618
# Epoch 17/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.1596 - accuracy: 0.9581 - val_loss: 0.1428 - val_accuracy: 0.9644
# Epoch 18/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.1510 - accuracy: 0.9603 - val_loss: 0.1473 - val_accuracy: 0.9627
# Epoch 19/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.1514 - accuracy: 0.9600 - val_loss: 0.1392 - val_accuracy: 0.9633
# Epoch 20/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1515 - accuracy: 0.9601 - val_loss: 0.1422 - val_accuracy: 0.9638
# Epoch 21/50
# 329/329 [==============================] - 1s 5ms/step - loss: 0.1436 - accuracy: 0.9611 - val_loss: 0.1440 - val_accuracy: 0.9645
# Epoch 22/50
# 329/329 [==============================] - 1s 5ms/step - loss: 0.1460 - accuracy: 0.9617 - val_loss: 0.1394 - val_accuracy: 0.9650
# Epoch 23/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.1387 - accuracy: 0.9641 - val_loss: 0.1457 - val_accuracy: 0.9632
# Epoch 24/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1371 - accuracy: 0.9634 - val_loss: 0.1376 - val_accuracy: 0.9651
# Epoch 25/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1399 - accuracy: 0.9631 - val_loss: 0.1410 - val_accuracy: 0.9643
# Epoch 26/50
# 329/329 [==============================] - 1s 5ms/step - loss: 0.1354 - accuracy: 0.9650 - val_loss: 0.1291 - val_accuracy: 0.9664
# Epoch 27/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1316 - accuracy: 0.9651 - val_loss: 0.1420 - val_accuracy: 0.9647
# Epoch 28/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1333 - accuracy: 0.9638 - val_loss: 0.1364 - val_accuracy: 0.9663
# Epoch 29/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1285 - accuracy: 0.9674 - val_loss: 0.1331 - val_accuracy: 0.9682
# Epoch 30/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1320 - accuracy: 0.9655 - val_loss: 0.1377 - val_accuracy: 0.9663
# Epoch 31/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.1237 - accuracy: 0.9668 - val_loss: 0.1438 - val_accuracy: 0.9656
# Epoch 32/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1243 - accuracy: 0.9666 - val_loss: 0.1397 - val_accuracy: 0.9663
# Epoch 33/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1167 - accuracy: 0.9678 - val_loss: 0.1374 - val_accuracy: 0.9670
# Epoch 34/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1227 - accuracy: 0.9673 - val_loss: 0.1301 - val_accuracy: 0.9680
# Epoch 35/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1175 - accuracy: 0.9683 - val_loss: 0.1422 - val_accuracy: 0.9646
# Epoch 36/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1201 - accuracy: 0.9676 - val_loss: 0.1361 - val_accuracy: 0.9662
# Epoch 37/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1177 - accuracy: 0.9686 - val_loss: 0.1394 - val_accuracy: 0.9656
# Epoch 38/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1153 - accuracy: 0.9688 - val_loss: 0.1400 - val_accuracy: 0.9652
# Epoch 39/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1120 - accuracy: 0.9693 - val_loss: 0.1388 - val_accuracy: 0.9672
# Epoch 40/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1147 - accuracy: 0.9688 - val_loss: 0.1359 - val_accuracy: 0.9666
# Epoch 41/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1109 - accuracy: 0.9704 - val_loss: 0.1410 - val_accuracy: 0.9666
# Epoch 42/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1104 - accuracy: 0.9702 - val_loss: 0.1393 - val_accuracy: 0.9648
# Epoch 43/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1103 - accuracy: 0.9700 - val_loss: 0.1425 - val_accuracy: 0.9669
# Epoch 44/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1108 - accuracy: 0.9703 - val_loss: 0.1464 - val_accuracy: 0.9659
# Epoch 45/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1077 - accuracy: 0.9710 - val_loss: 0.1346 - val_accuracy: 0.9669
# Epoch 46/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1095 - accuracy: 0.9702 - val_loss: 0.1369 - val_accuracy: 0.9681
# Epoch 47/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1101 - accuracy: 0.9703 - val_loss: 0.1371 - val_accuracy: 0.9666
# Epoch 48/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1047 - accuracy: 0.9718 - val_loss: 0.1356 - val_accuracy: 0.9679
# Epoch 49/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1027 - accuracy: 0.9719 - val_loss: 0.1380 - val_accuracy: 0.9677
# Epoch 50/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1036 - accuracy: 0.9719 - val_loss: 0.1530 - val_accuracy: 0.9648

# %% [markdown]
# Considerations: what can you notice from these results? Has the accuracy increased?

# %% [markdown]
# **Results**: Now seems better, there is an increase in the accuracy.

# %% [markdown]
# ### 5. Make the model "wide" and "deep": more hidden layers, each with more than 50 neurons.

# %% [markdown]
# **Define the new variables.**

# %%
input_num_units = 784
hidden1_num_units = 500
hidden2_num_units = 500
hidden3_num_units = 500
hidden4_num_units = 500
hidden5_num_units = 500
output_num_units = 10

epochs = 25
batch_size = 128

# %% [markdown]
# **Build the network.**

# %%
model_5 = models.Sequential()

model_5.add(layers.Dense(units=hidden1_num_units, input_shape=(input_num_units,), activation='relu'))
model_5.add(layers.Dropout(0.2))
model_5.add(layers.Dense(units=hidden2_num_units,  activation='relu'))
model_5.add(layers.Dropout(0.2))
model_5.add(layers.Dense(units=hidden3_num_units,  activation='relu'))
model_5.add(layers.Dropout(0.2))
model_5.add(layers.Dense(units=hidden4_num_units,  activation='relu'))
model_5.add(layers.Dropout(0.2))
model_5.add(layers.Dense(units=hidden5_num_units, activation='relu'))
model_5.add(layers.Dropout(0.2))

model_5.add(layers.Dense(units=output_num_units,  activation='softmax'))

# %% [markdown]
# **Configure the network.**

# %%
model_5.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# **Train the network. Use 25 epochs if 50 takes too long.**

# %%
trained_model_5 = model_5.fit(train_images, train_labels, epochs=epochs, 
                              batch_size=batch_size, validation_data=(val_images, val_labels))
# Out:
# Epoch 1/25
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x15577a8c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x15577a8c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 328/329 [============================>.] - ETA: 0s - loss: 0.3669 - accuracy: 0.8865WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x155704b00> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x155704b00> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 329/329 [==============================] - 11s 32ms/step - loss: 0.3667 - accuracy: 0.8865 - val_loss: 0.1497 - val_accuracy: 0.9551
# Epoch 2/25
# 329/329 [==============================] - 11s 32ms/step - loss: 0.1489 - accuracy: 0.9556 - val_loss: 0.1163 - val_accuracy: 0.9669
# Epoch 3/25
# 329/329 [==============================] - 10s 30ms/step - loss: 0.1091 - accuracy: 0.9677 - val_loss: 0.1016 - val_accuracy: 0.9713
# Epoch 4/25
# 329/329 [==============================] - 10s 29ms/step - loss: 0.0884 - accuracy: 0.9731 - val_loss: 0.1066 - val_accuracy: 0.9697
# Epoch 5/25
# 329/329 [==============================] - 10s 32ms/step - loss: 0.0759 - accuracy: 0.9775 - val_loss: 0.1064 - val_accuracy: 0.9728
# Epoch 6/25
# 329/329 [==============================] - 10s 32ms/step - loss: 0.0676 - accuracy: 0.9799 - val_loss: 0.1033 - val_accuracy: 0.9741
# Epoch 7/25
# 329/329 [==============================] - 10s 31ms/step - loss: 0.0600 - accuracy: 0.9823 - val_loss: 0.0993 - val_accuracy: 0.9728
# Epoch 8/25
# 329/329 [==============================] - 13s 39ms/step - loss: 0.0488 - accuracy: 0.9853 - val_loss: 0.1058 - val_accuracy: 0.9757
# Epoch 9/25
# 329/329 [==============================] - 11s 34ms/step - loss: 0.0502 - accuracy: 0.9850 - val_loss: 0.1014 - val_accuracy: 0.9756
# Epoch 10/25
# 329/329 [==============================] - 10s 31ms/step - loss: 0.0449 - accuracy: 0.9870 - val_loss: 0.1148 - val_accuracy: 0.9742
# Epoch 11/25
# 329/329 [==============================] - 10s 32ms/step - loss: 0.0418 - accuracy: 0.9877 - val_loss: 0.1063 - val_accuracy: 0.9767
# Epoch 12/25
# 329/329 [==============================] - 11s 32ms/step - loss: 0.0414 - accuracy: 0.9883 - val_loss: 0.1021 - val_accuracy: 0.9754
# Epoch 13/25
# 329/329 [==============================] - 10s 31ms/step - loss: 0.0356 - accuracy: 0.9890 - val_loss: 0.1211 - val_accuracy: 0.9762
# Epoch 14/25
# 329/329 [==============================] - 11s 32ms/step - loss: 0.0342 - accuracy: 0.9901 - val_loss: 0.1093 - val_accuracy: 0.9786
# Epoch 15/25
# 329/329 [==============================] - 10s 30ms/step - loss: 0.0314 - accuracy: 0.9899 - val_loss: 0.1266 - val_accuracy: 0.9766
# Epoch 16/25
# 329/329 [==============================] - 10s 32ms/step - loss: 0.0325 - accuracy: 0.9905 - val_loss: 0.1284 - val_accuracy: 0.9767
# Epoch 17/25
# 329/329 [==============================] - 10s 30ms/step - loss: 0.0278 - accuracy: 0.9918 - val_loss: 0.1120 - val_accuracy: 0.9767
# Epoch 18/25
# 329/329 [==============================] - 9s 29ms/step - loss: 0.0330 - accuracy: 0.9910 - val_loss: 0.1199 - val_accuracy: 0.9768
# Epoch 19/25
# 329/329 [==============================] - 10s 30ms/step - loss: 0.0297 - accuracy: 0.9917 - val_loss: 0.1304 - val_accuracy: 0.9769
# Epoch 20/25
# 329/329 [==============================] - 10s 30ms/step - loss: 0.0276 - accuracy: 0.9923 - val_loss: 0.1190 - val_accuracy: 0.9758
# Epoch 21/25
# 329/329 [==============================] - 10s 30ms/step - loss: 0.0271 - accuracy: 0.9927 - val_loss: 0.1343 - val_accuracy: 0.9778
# Epoch 22/25
# 329/329 [==============================] - 10s 30ms/step - loss: 0.0232 - accuracy: 0.9934 - val_loss: 0.1151 - val_accuracy: 0.9784
# Epoch 23/25
# 329/329 [==============================] - 10s 30ms/step - loss: 0.0223 - accuracy: 0.9939 - val_loss: 0.1468 - val_accuracy: 0.9778
# Epoch 24/25
# 329/329 [==============================] - 10s 31ms/step - loss: 0.0223 - accuracy: 0.9933 - val_loss: 0.1390 - val_accuracy: 0.9764
# Epoch 25/25
# 329/329 [==============================] - 10s 29ms/step - loss: 0.0268 - accuracy: 0.9928 - val_loss: 0.1345 - val_accuracy: 0.9787

# %% [markdown]
# Considerations: what do you think about your final model?
# It seems that we obtained our final solution model. Let's evaluate it with some predictions.

# %% [markdown]
# **Make some predictions and Evaluate the network.**

# %%
from sklearn.metrics import confusion_matrix

pred = np.argmax(model_5.predict(test_images), axis=-1)
label = np.argmax(test_labels, axis = 1)

confusion = confusion_matrix(label, pred)
print(confusion)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x15558b710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x15558b710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# [[ 974    0    1    1    0    0    2    1    1    0]
#  [   0 1126    2    1    0    2    1    0    3    0]
#  [   3    0 1014    1    2    0    3    6    3    0]
#  [   1    0    2  999    0    2    0    3    3    0]
#  [   1    2    1    1  960    0    7    2    1    7]
#  [   3    0    0    3    1  877    2    1    3    2]
#  [   4    4    0    1    1    3  943    0    2    0]
#  [   0    4    8    4    0    0    0 1007    3    2]
#  [   5    1    4    3    2    1    1    2  953    2]
#  [   3    6    0    6   12    2    2    4    2  972]]

# %%
test_loss_final, test_acc_final = model_5.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1146 - accuracy: 0.9825

# %%
print('test_acc:', test_acc_final)
# Out:
# test_acc: 0.9825000166893005

# %% [markdown]
# **Results**: Finally we get our very good model!

# %% [markdown]
# ### Hyperparameters Optimization - Grid Search
#
# Instead of proceeding with a "trial and error" approach we can also use GridSearch to combine all the hyperparameters we want to tune. The Grid search works by trying every possible combination of parameters you want to try, therefore it will take a lot of time to perform the entire search.
#
# Grid search is a simple and naive, yet effective method to automate the hyperparameter tuning:
#
# * First, you define the set of hyperparameters you want to tune, e.g. $\{neurons, learning\_rate, regularization\_strength\}$.
#
# * For each hyperparameter, you then define a set of possible values, e.g. $neurons = \{50, 100, 250, 500\}$.
#
# * Then, you train a model for every possible combination of these hyperparameter values and afterwards select the combination that works best (e.g. in terms of accuracy on your validation set).
#
# What you have to do is to use Sequential() model in Keras as a part of the Scikit-Learn workflow via the wrappers.
# Check out how this [workflow](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html?highlight=gridsearch#sklearn.model_selection.GridSearchCV) works.
# **Note**: to keep things simple for the beginning, it'll be enough to just focus on the hyperparameters `neurons`
#
# Please note that without GPU is extremely time consuming to tune all the hyperparameters in one shoot, by using an appropriate number of epochs. For this reason, in this example the idea is for you to understand how you can use GridSerach with Keras Model, but you will probably not be able to obtain an excellent model.
#
# For this reason, try to tune the number of neurons in the hidden layers (more than one hidden layer) with just 5-10 epochs.

# %% [markdown]
# **Import GridSearchCV and KerasClassifier.**

# %%
import numpy
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.constraints import MaxNorm

# %%
input_num_units = 784
output_num_units = 10

# %% [markdown]
# **Create a function called `create_model` in which you build your KerasClassifier with number of hidden units equal to a general variable (you can call this `neurons`). Inside the function you should then also compile the model.**

# %%
# Function to create model, required for KerasClassifier
def create_model(neurons=1):
  
    model = models.Sequential()  
    model.add(layers.Dense(units=neurons, input_shape=(input_num_units,), activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(units=neurons, activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(units=neurons, activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(units=neurons, activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(units=neurons, activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(units=output_num_units, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %% [markdown]
# **Create a model wrapper.**

# %%
clf = KerasClassifier(build_fn=create_model, epochs=5, batch_size=32, verbose=1)

# %% [markdown]
# **Create a dictionary of parameters grid for the number of neurons in the hidden layer.**

# %%
neurons = [50, 100, 250, 500]
param_grid = dict(neurons=neurons)

# %%
param_grid
# Out:
# {'neurons': [50, 100, 250, 500]}

# %% [markdown]
# **Grid Search: use `GridSearchCV`with the model you have obtained from the wrapper as estimator and the dictionary you have just created as param_grid.**

# %%
grid = GridSearchCV(estimator=clf, param_grid=param_grid, n_jobs=None)

# %% [markdown]
# **Fit the result from the Grid Search, call your result `grid_result`.**

# %%
grid_result = grid.fit(train_images, train_labels, validation_data = (val_images, val_labels), epochs=5)
# Out:
# Epoch 1/5
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x15577a950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x15577a950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1045/1050 [============================>.] - ETA: 0s - loss: 0.8483 - accuracy: 0.7232WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x15567f050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x15567f050> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1050/1050 [==============================] - 5s 4ms/step - loss: 0.8468 - accuracy: 0.7238 - val_loss: 0.2889 - val_accuracy: 0.9199
# Epoch 2/5
# 1050/1050 [==============================] - 4s 4ms/step - loss: 0.4077 - accuracy: 0.8912 - val_loss: 0.2351 - val_accuracy: 0.9339
# Epoch 3/5
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.3387 - accuracy: 0.9109 - val_loss: 0.2091 - val_accuracy: 0.9431
# Epoch 4/5
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.3010 - accuracy: 0.9209 - val_loss: 0.1933 - val_accuracy: 0.9487
# Epoch 5/5
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2767 - accuracy: 0.9271 - val_loss: 0.1777 - val_accuracy: 0.9521
# 263/263 [==============================] - 1s 2ms/step - loss: 0.1676 - accuracy: 0.9557
# Epoch 1/5
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x156b557a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x156b557a0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1046/1050 [============================>.] - ETA: 0s - loss: 0.8186 - accuracy: 0.7344WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x157409440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x157409440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1050/1050 [==============================] - 4s 3ms/step - loss: 0.8170 - accuracy: 0.7350 - val_loss: 0.2953 - val_accuracy: 0.9176
# Epoch 2/5
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0
https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html). Random search is very similar to grid search, with the only difference, that instead of providing specific values for every hyperparameter, you only define a range for each hyperparameter - then, the values are sampled randomly from the provided ranges. The number of parameter settings that are tried is given by n_iter.
# ![alt text](https://i.stack.imgur.com/cIDuR.png "")
#
# The figure above illustrates the difference in the hyperparameter space exploration between grid search and random search: assume you have 2 hyperparameters with each 3 values. Running a grid search results in training $3^2=9$ different models - but in the end, you've just tired out 3 values for each parameter. For random search on the other hand, after training 9 models you'll have tried out 9 different values for each hyperparameter, which often leads much faster to good results.
#
# To get a deeper understanding of random search and why it is more efficient than grid search, you should definitely check out this paper: http://www.jmlr.org/papers/volume13/bergstra12a/bergstra12a.pdf.

# %% [markdown]
# **Import RandomizedSearchCV.**

# %%
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# **Random Search: use `RandomizedSearchCV` with the model you have obtained from the wrapper as estimator and the dictionary you have created for GridSearch as param_distributions.**

# %%
# We reuse the estimator wrapper and the param_grid defined for GridSearch
print(param_grid)
random = RandomizedSearchCV(estimator=clf, param_distributions=param_grid, n_iter=2, n_jobs=None)
# Out:
# {'neurons': [50, 100, 250, 500]}

# %% [markdown]
# **Fit the result from the Grid Search, call your result `random_result`.**

# %%
random_result = random.fit(train_images, train_labels, validation_data = (val_images, val_labels), epochs=1)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x190035320> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x190035320> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1041/1050 [============================>.] - ETA: 0s - loss: 0.5886 - accuracy: 0.8158WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x177828320> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x177828320> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1050/1050 [==============================] - 5s 4ms/step - loss: 0.5865 - accuracy: 0.8167 - val_loss: 0.2003 - val_accuracy: 0.9427
# 263/263 [==============================] - 1s 2ms/step - loss: 0.1892 - accuracy: 0.9492
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x15881f4d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x15881f4d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1048/1050 [============================>.] - ETA: 0s - loss: 0.5623 - accuracy: 0.8265WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x15709d3b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x15709d3b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1050/1050 [==============================] - 6s 5ms/step - loss: 0.5621 - accuracy: 0.8266 - val_loss: 0.2045 - val_accuracy: 0.9401
# 263/263 [==============================] - 1s 3ms/step - loss: 0.2307 - accuracy: 0.9317
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x17fb4a560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x17fb4a560> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1048/1050 [============================>.] - ETA: 0s - loss: 0.5853 - accuracy: 0.8194 ETA: 0s - lWARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x16f5a6440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x16f5a6440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1050/1050 [==============================] - 6s 5ms/step - loss: 0.5852 - accuracy: 0.8195 - val_loss: 0.2195 - val_accuracy: 0.9329
# 263/263 [==============================] - 1s 3ms/step - loss: 0.2062 - accuracy: 0.9396
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x1673173b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x1673173b0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1040/1050 [============================>.] - ETA: 0s - loss: 0.5893 - accuracy: 0.8130WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1900674d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1900674d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1050/1050 [==============================] - 5s 4ms/step - loss: 0.5862 - accuracy: 0.8141 - val_loss: 0.2061 - val_accuracy: 0.9402
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2289 - accuracy: 0.9324
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x177720320> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x177720320> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1044/1050 [============================>.] - ETA: 0s - loss: 0.5858 - accuracy: 0.8154WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x158529440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x158529440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1050/1050 [==============================] - 5s 4ms/step - loss: 0.5843 - accuracy: 0.8161 - val_loss: 0.2172 - val_accuracy: 0.9363
# 263/263 [==============================] - 1s 2ms/step - loss: 0.2267 - accuracy: 0.9325
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x16f45e5f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x16f45e5f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1048/1050 [============================>.] - ETA: 0s - loss: 0.3556 - accuracy: 0.8927WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x15859dcb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x15859dcb0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1050/1050 [==============================] - 20s 18ms/step - loss: 0.3560 - accuracy: 0.8927 - val_loss: 0.2186 - val_accuracy: 0.9401
# 263/263 [==============================] - 1s 5ms/step - loss: 0.1958 - accuracy: 0.9469
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x155569b00> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x155569b00> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1047/1050 [============================>.] - ETA: 0s - loss: 0.3605 - accuracy: 0.8924WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x15881d680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x15881d680> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1050/1050 [==============================] - 18s 17ms/step - loss: 0.3598 - accuracy: 0.8926 - val_loss: 0.1706 - val_accuracy: 0.9506
# 263/263 [==============================] - 1s 5ms/step - loss: 0.1919 - accuracy: 0.9488
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x156c71830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x156c71830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1047/1050 [============================>.] - ETA: 0s - loss: 0.3704 - accuracy: 0.8908WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x187e42440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x187e42440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1050/1050 [==============================] - 18s 17ms/step - loss: 0.3705 - accuracy: 0.8910 - val_loss: 0.1837 - val_accuracy: 0.9492
# 263/263 [==============================] - 2s 5ms/step - loss: 0.1834 - accuracy: 0.9486
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x187f29290> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x187f29290> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1047/1050 [============================>.] - ETA: 0s - loss: 0.3531 - accuracy: 0.8953WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x16f435d40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x16f435d40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1050/1050 [==============================] - 17s 16ms/step - loss: 0.3526 - accuracy: 0.8955 - val_loss: 0.1692 - val_accuracy: 0.9514
# 263/263 [==============================] - 2s 6ms/step - loss: 0.1838 - accuracy: 0.9480
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x190276f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x190276f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1048/1050 [============================>.] - ETA: 0s - loss: 0.3555 - accuracy: 0.8927WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x17fa4b8c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x17fa4b8c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1050/1050 [==============================] - 19s 18ms/step - loss: 0.3551 - accuracy: 0.8929 - val_loss: 0.2126 - val_accuracy: 0.9394
# 263/263 [==============================] - 2s 6ms/step - loss: 0.2224 - accuracy: 0.9390
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x158886a70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x158886a70> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1312/1313 [============================>.] - ETA: 0s - loss: 0.3335 - accuracy: 0.9026WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x158653440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x158653440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1313/1313 [==============================] - 25s 19ms/step - loss: 0.3336 - accuracy: 0.9026 - val_loss: 0.1770 - val_accuracy: 0.9498

# %% [markdown]
# **Let's print some results. Fill in the #TO DOs with the best_score and best_params that you got after fitting.**

# %%
print("Best: %f using %s" % (random_result.best_score_, random_result.best_params_)) #TO DO, #TO DO
means = random_result.cv_results_['mean_test_score']
stds = random_result.cv_results_['std_test_score']
params = random_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.946262 using {'neurons': 500}
# 0.937071 (0.006708) with: {'neurons': 100}
# 0.946262 (0.003667) with: {'neurons': 500}

# %% [markdown]
# ### Hyperparameters Optimization - Bayesian Optimization

# %% [markdown]
# Manual tuning (Trial and Error), grid search and random search are considered brute-force methods.
# Grid search is an exhaustive approach to evaluate the hyperparameter values defined in a grid.
# The random search approach will randomly choose the values for the hyperparameters. Grid and
# random search perform better than manual tuning, but they do not consider past evaluations.
# Hence, they lose significant time evaluating hyperparameters in the same inadequate region.
# Furthermore, the objective functions to minimize are computationally expensive and running
# them each time with a new set of parameters is time-demanding.
# Therefore, Bergstra et al. proposed a model-based method called Sequential Model-Based Optimization (SMBO).
# The main idea of this approach is to create a surrogate model of the objective function using a
# probabilistic distribution. This surrogate model bases on the Bayes’ theorem. At each new iteration, the surrogate will become more and more confident about which new guess can lead to improvements.

# %% [markdown]
# For this we will use the package [hyperopt](http://hyperopt.github.io/hyperopt/)
#
# ````pip install hyperopt````

# %% [markdown]
# **The data for the optimizer should be returned from a function ````get_data````**

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
import numpy as np


def get_data():
    (train_images, train_labels), (test_images, test_labels) = mnist.load_data() 
    train_images = train_images.reshape((60000, 28 * 28))
    train_images = train_images.astype('float32') / 255

    test_images = test_images.reshape((10000, 28 * 28))
    test_images = test_images.astype('float32') / 255
    # We need to encode the categorical labels in one-hot format
    train_labels = to_categorical(train_labels)
    test_labels = to_categorical(test_labels)

    return train_images, train_labels, test_images, test_labels

# %% [markdown]
# **Use Hyperopt for hyperparameter tunning**

# %%
import numpy as np
from hyperopt import Trials, STATUS_OK, tpe, fmin, hp
# Import Keras modules
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers

# Function to create model
def f_nn(params):
    train_images,train_labels, test_images, test_labels = get_data()
  
    model = models.Sequential()  
    # Notice here how we define the number of neurons per layer
    model.add(layers.Dense(units=params['units_1'], input_shape=(28*28,), activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(units=params['units_2'], activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(units=params['units_3'], activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(units=params['units_4'], activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(units=params['units_5'], activation='relu'))
    model.add(layers.Dropout(0.2))
    model.add(layers.Dense(units=10, activation='softmax'))
    # model_compile
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    # model fitting
    result = model.fit(train_images, train_labels, epochs=2, 
              batch_size=128, validation_split=0.3)
    
    # Get the lowest validation loss of the training epochs
    validation_loss = np.amin(result.history['val_loss']) 
    print('Best validation loss of epoch:', validation_loss)
    
    score = model.evaluate(test_images, test_labels, verbose=0)
    accuracy = score[1]
    return {'loss': -accuracy,'status': STATUS_OK, 'model': model, 'params':params}

# %%
space = {'units_1':hp.choice('units_1', [50,100,250,500]),
         'units_2':hp.choice('units_2', [50,100,250,500]),
         'units_3':hp.choice('units_3', [50,100,250,500]),
         'units_4':hp.choice('units_4', [50,100,250,500]),
         'units_5':hp.choice('units_5', [50,100,250,500])}

# %%
trials = Trials()
best = fmin( 
    fn=f_nn,
    space=space,
    algo=tpe.suggest,
    max_evals=5,
    trials=trials,
    rstate = np.random.default_rng(42))
# Out:
# Epoch 1/2
#   0%|                                     | 0/5 [00:00<?, ?trial/s, best loss=?]WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x154dc9b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x154dc9b90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#   1/329 [..............................]
#  - ETA: 4:19 - loss: 2.2996 - accuracy: 0.1250
#
#   3/329 [..............................]
#  - ETA: 11s - loss: 2.2895 - accuracy: 0.1328
#
#   4/329 [..............................]
#  - ETA: 16s - loss: 2.2828 - accuracy: 0.1465
#
#   7/329 [..............................]
#  - ETA: 11s - loss: 2.2586 - accuracy: 0.1708
#
#  11/329 [>.............................]
#  - ETA: 8s - loss: 2.1953 - accuracy: 0.2131
#
#  13/329 [>.............................]
#  - ETA: 8s - loss: 2.1497 - accuracy: 0.2428
#
#  15/329 [>.............................]
#  - ETA: 8s - loss: 2.1013 - accuracy: 0.2677
#
#  16/329 [>.............................]
#  - ETA: 9s - loss: 2.0795 - accuracy: 0.2764
#
#  17/329 [>.............................]
#  - ETA: 10s - loss: 2.0466 - accuracy: 0.2904
#
#  18/329 [>.............................]
#  - ETA: 10s - loss: 2.0249 - accuracy: 0.3021
#
#  19/329 [>.............................]
#  - ETA: 11s - loss: 2.0017 - accuracy: 0.3104
#
#  20/329 [>.............................]
#  - ETA: 11s - loss: 1.9727 - accuracy: 0.3199
#
#  21/329 [>.............................]
#  - ETA: 12s - loss: 1.9435 - accuracy: 0.3315
#
#  23/329 [=>............................]
#  - ETA: 12s - loss: 1.8921 - accuracy: 0.3502
#
#  25/329 [=>............................]
#  - ETA: 11s - loss: 1.8437 - accuracy: 0.3644
#
#  28/329 [=>............................]
#  - ETA: 10s - loss: 1.7768 - accuracy: 0.3859
#
#  29/329 [=>............................]
#  - ETA: 11s - loss: 1.7508 - accuracy: 0.3941
#
#  30/329 [=>............................]
#  - ETA: 11s - loss: 1.7278 - accuracy: 0.4013
#
#  31/329 [=>............................]
#  - ETA: 11s - loss: 1.7056 - accuracy: 0.4103
#
#  32/329 [=>............................]
#  - ETA: 11s - loss: 1.6802 - accuracy: 0.4182
#
#  33/329 [==>...........................]
#  - ETA: 12s - loss: 1.6603 - accuracy: 0.4257
#
#  34/329 [==>...........................]
#  - ETA: 12s - loss: 1.6409 - accuracy: 0.4324
#
#  37/329 [==>...........................]
#  - ETA: 11s - loss: 1.5788 - accuracy: 0.4565
#
#  38/329 [==>...........................]
#  - ETA: 11s - loss: 1.5605 - accuracy: 0.4628
#
#  40/329 [==>...........................]
#  - ETA: 11s - loss: 1.5338 - accuracy: 0.4727
#
#  41/329 [==>...........................]
#  - ETA: 11s - loss: 1.5156 - accuracy: 0.4792
#
#  43/329 [==>...........................]
#  - ETA: 11s - loss: 1.4852 - accuracy: 0.4902
#
#  45/329 [===>..........................]
#  - ETA: 11s - loss: 1.4569 - accuracy: 0.5007
#
#  47/329 [===>..........................]
#  - ETA: 10s - loss: 1.4293 - accuracy: 0.5106
#
#  48/329 [===>..........................]
#  - ETA: 11s - loss: 1.4157 - accuracy: 0.5151
#
#  49/329 [===>..........................]
#  - ETA: 11s - loss: 1.4015 - accuracy: 0.5201
#
#  50/329 [===>..........................]
#  - ETA: 11s - loss: 1.3912 - accuracy: 0.5238
#
#  51/329 [===>..........................]
#  - ETA: 11s - loss: 1.3793 - accuracy: 0.5280
#
#  52/329 [===>..........................]
#  - ETA: 11s - loss: 1.3668 - accuracy: 0.5328
#
#  53/329 [===>..........................]
#  - ETA: 11s - loss: 1.3537 - accuracy: 0.5373
#
#  54/329 [===>..........................]
#  - ETA: 11s - loss: 1.3431 - accuracy: 0.5411
#
#  55/329 [====>.........................]
#  - ETA: 12s - loss: 1.3339 - accuracy: 0.5442
#
#  56/329 [====>.........................]
#  - ETA: 12s - loss: 1.3219 - accuracy: 0.5490
#
#  57/329 [====>.........................]
#  - ETA: 12s - loss: 1.3110 - accuracy: 0.5532
#
#  61/329 [====>.........................]
#  - ETA: 11s - loss: 1.2730 - accuracy: 0.5680
#
#  65/329 [====>.........................]
#  - ETA: 11s - loss: 1.2342 - accuracy: 0.5815
#
#  69/329 [=====>........................]
#  - ETA: 10s - loss: 1.1962 - accuracy: 0.5947
#
#  72/329 [=====>........................]
#  - ETA: 10s - loss: 1.1692 - accuracy: 0.6050
#
#  75/329 [=====>........................]
#  - ETA: 9s - loss: 1.1445 - accuracy: 0.6136
#
#  77/329 [======>.......................]
#  - ETA: 9s - loss: 1.1257 - accuracy: 0.6203
#
#  78/329 [======>.......................]
#  - ETA: 9s - loss: 1.1166 - accuracy: 0.6236
#
#  79/329 [======>.......................]
#  - ETA: 9s - loss: 1.1084 - accuracy: 0.6267
#
#  80/329 [======>.......................]
#  - ETA: 9s - loss: 1.1006 - accuracy: 0.6294
#
#  81/329 [======>.......................]
#  - ETA: 9s - loss: 1.0946 - accuracy: 0.6316
#
#  84/329 [======>.......................]
#  - ETA: 9s - loss: 1.0739 - accuracy: 0.6393
#
#  87/329 [======>.......................]
#  - ETA: 9s - loss: 1.0531 - accuracy: 0.6465
#
#  90/329 [=======>......................]
#  - ETA: 8s - loss: 1.0349 - accuracy: 0.6530
#
#  92/329 [=======>......................]
#  - ETA: 8s - loss: 1.0264 - accuracy: 0.6558
#
#  94/329 [=======>......................]
#  - ETA: 8s - loss: 1.0137 - accuracy: 0.6600
#
#  96/329 [=======>......................]
#  - ETA: 8s - loss: 1.0013 - accuracy: 0.6646
#
#  99/329 [========>.....................]
#  - ETA: 8s - loss: 0.9893 - accuracy: 0.6696
#
# 100/329 [========>.....................]
#  - ETA: 8s - loss: 0.9842 - accuracy: 0.6716
#
# 102/329 [========>.....................]
#  - ETA: 8s - loss: 0.9745 - accuracy: 0.6752
#
# 105/329 [========>.....................]
#  - ETA: 7s - loss: 0.9586 - accuracy: 0.6807
#
# 108/329 [========>.....................]
#  - ETA: 7s - loss: 0.9471 - accuracy: 0.6855
#
# 111/329 [=========>....................]
#  - ETA: 7s - loss: 0.9339 - accuracy: 0.6907
#
# 112/329 [=========>....................]
#  - ETA: 7s - loss: 0.9299 - accuracy: 0.6924
#
# 113/329 [=========>....................]
#  - ETA: 7s - loss: 0.9251 - accuracy: 0.6941
# 115/329 [=========>....................]
#  - ETA: 7s - loss: 0.9154 - accuracy: 0.6979
#
# 117/329 [=========>....................]
#  - ETA: 7s - loss: 0.9055 - accuracy: 0.7016
#
# 120/329 [=========>....................]
#  - ETA: 7s - loss: 0.8935 - accuracy: 0.7057
#
# 122/329 [==========>...................]
#  - ETA: 7s - loss: 0.8846 - accuracy: 0.7088
#
# 124/329 [==========>...................]
#  - ETA: 7s - loss: 0.8778 - accuracy: 0.7113
#
# 127/329 [==========>...................]
#  - ETA: 6s - loss: 0.8666 - accuracy: 0.7152
#
# 130/329 [==========>...................]
#  - ETA: 6s - loss: 0.8548 - accuracy: 0.7196
#
# 132/329 [===========>..................]
#  - ETA: 6s - loss: 0.8492 - accuracy: 0.7221
#
# 134/329 [===========>..................]
#  - ETA: 6s - loss: 0.8433 - accuracy: 0.7243
#
# 136/329 [===========>..................]
#  - ETA: 6s - loss: 0.8364 - accuracy: 0.7269
#
# 138/329 [===========>..................]
#  - ETA: 6s - loss: 0.8293 - accuracy: 0.7293
#
# 140/329 [===========>..................]
#  - ETA: 6s - loss: 0.8239 - accuracy: 0.7311
#
# 142/329 [===========>..................]
#  - ETA: 6s - loss: 0.8179 - accuracy: 0.7331
#
# 143/329 [============>.................]
#  - ETA: 6s - loss: 0.8153 - accuracy: 0.7342
#
# 144/329 [============>.................]
#  - ETA: 6s - loss: 0.8127 - accuracy: 0.7352
#
# 145/329 [============>.................]
#  - ETA: 6s - loss: 0.8091 - accuracy: 0.7365
#
# 146/329 [============>.................]
#  - ETA: 6s - loss: 0.8060 - accuracy: 0.7375
#
# 147/329 [============>.................]
#  - ETA: 6s - loss: 0.8043 - accuracy: 0.7381
#
# 149/329 [============>.................]
#  - ETA: 6s - loss: 0.7981 - accuracy: 0.7404
#
# 152/329 [============>.................]
#  - ETA: 5s - loss: 0.7892 - accuracy: 0.7433
#
# 155/329 [=============>................]
#  - ETA: 5s - loss: 0.7816 - accuracy: 0.7463
#
# 158/329 [=============>................]
#  - ETA: 5s - loss: 0.7732 - accuracy: 0.7491
#
# 160/329 [=============>................]
#  - ETA: 5s - loss: 0.7678 - accuracy: 0.7511
#
# 163/329 [=============>................]
#  - ETA: 5s - loss: 0.7613 - accuracy: 0.7537
#
# 166/329 [==============>...............]
#  - ETA: 5s - loss: 0.7541 - accuracy: 0.7563
#
# 168/329 [==============>...............]
#  - ETA: 5s - loss: 0.7502 - accuracy: 0.7576
#
# 171/329 [==============>...............]
#  - ETA: 5s - loss: 0.7429 - accuracy: 0.7601
#
# 174/329 [==============>...............]
#  - ETA: 4s - loss: 0.7369 - accuracy: 0.7624
#
# 176/329 [===============>..............]
#  - ETA: 4s - loss: 0.7331 - accuracy: 0.7640
#
# 179/329 [===============>..............]
#  - ETA: 4s - loss: 0.7264 - accuracy: 0.7666
#
# 181/329 [===============>..............]
#  - ETA: 4s - loss: 0.7216 - accuracy: 0.7683
#
# 184/329 [===============>..............]
#  - ETA: 4s - loss: 0.7158 - accuracy: 0.7703
#
# 187/329 [================>.............]
#  - ETA: 4s - loss: 0.7104 - accuracy: 0.7724
#
# 189/329 [================>.............]
#  - ETA: 4s - loss: 0.7062 - accuracy: 0.7739
#
# 192/329 [================>.............]
#  - ETA: 4s - loss: 0.6995 - accuracy: 0.7763
#
# 195/329 [================>.............]
#  - ETA: 4s - loss: 0.6939 - accuracy: 0.7783
#
# 198/329 [=================>............]
#  - ETA: 4s - loss: 0.6890 - accuracy: 0.7803
#
# 201/329 [=================>............]
#  - ETA: 3s - loss: 0.6823 - accuracy: 0.7827
#
# 204/329 [=================>............]
#  - ETA: 3s - loss: 0.6764 - accuracy: 0.7847
#
# 206/329 [=================>............]
#  - ETA: 3s - loss: 0.6731 - accuracy: 0.7856
#
# 209/329 [==================>...........]
#  - ETA: 3s - loss: 0.6680 - accuracy: 0.7875
#
# 212/329 [==================>...........]
#  - ETA: 3s - loss: 0.6639 - accuracy: 0.7888
#
# 215/329 [==================>...........]
#  - ETA: 3s - loss: 0.6588 - accuracy: 0.7904
#
# 217/329 [==================>...........]
#  - ETA: 3s - loss: 0.6557 - accuracy: 0.7915
#
# 219/329 [==================>...........]
#  - ETA: 3s - loss: 0.6522 - accuracy: 0.7926
#
# 220/329 [===================>..........]
#  - ETA: 3s - loss: 0.6507 - accuracy: 0.7930
#
# 222/329 [===================>..........]
#  - ETA: 3s - loss: 0.6482 - accuracy: 0.7939
#
# 224/329 [===================>..........]
#  - ETA: 3s - loss: 0.6457 - accuracy: 0.7947
#
# 226/329 [===================>..........]
#  - ETA: 3s - loss: 0.6424 - accuracy: 0.7958
#
# 227/329 [===================>..........]
#  - ETA: 3s - loss: 0.6408 - accuracy: 0.7964
#
# 228/329 [===================>..........]
#  - ETA: 3s - loss: 0.6405 - accuracy: 0.7967
#
# 229/329 [===================>..........]
#  - ETA: 3s - loss: 0.6394 - accuracy: 0.7971
#
# 230/329 [===================>..........]
#  - ETA: 3s - loss: 0.6380 - accuracy: 0.7977
#
# 231/329 [====================>.........]
#  - ETA: 3s - loss: 0.6363 - accuracy: 0.7983
#
# 232/329 [====================>.........]
#  - ETA: 3s - loss: 0.6355 - accuracy: 0.7986
#
# 234/329 [====================>.........]
#  - ETA: 3s - loss: 0.6322 - accuracy: 0.7998
#
# 237/329 [====================>.........]
#  - ETA: 2s - loss: 0.6275 - accuracy: 0.8013
#
# 239/329 [====================>.........]
#  - ETA: 2s - loss: 0.6256 - accuracy: 0.8020
#
# 242/329 [=====================>........]
#  - ETA: 2s - loss: 0.6211 - accuracy: 0.8038
#
# 243/329 [=====================>........]
#  - ETA: 2s - loss: 0.6194 - accuracy: 0.8043
#
# 244/329 [=====================>........]
#  - ETA: 2s - loss: 0.6187 - accuracy: 0.8046
#
# 245/329 [=====================>........]
#  - ETA: 2s - loss: 0.6174 - accuracy: 0.8050
#
# 247/329 [=====================>........]
#  - ETA: 2s - loss: 0.6154 - accuracy: 0.8057
#
# 249/329 [=====================>........]
#  - ETA: 2s - loss: 0.6134 - accuracy: 0.8065
#
# 252/329 [=====================>........]
#  - ETA: 2s - loss: 0.6091 - accuracy: 0.8079
#
# 254/329 [======================>.......]
#  - ETA: 2s - loss: 0.6069 - accuracy: 0.8087
#
# 255/329 [======================>.......]
#  - ETA: 2s - loss: 0.6057 - accuracy: 0.8092
#
# 256/329 [======================>.......]
#  - ETA: 2s - loss: 0.6048 - accuracy: 0.8095
#
# 258/329 [======================>.......]
#  - ETA: 2s - loss: 0.6025 - accuracy: 0.8102
#
# 261/329 [======================>.......]
#  - ETA: 2s - loss: 0.5990 - accuracy: 0.8113
#
# 264/329 [=======================>......]
#  - ETA: 2s - loss: 0.5957 - accuracy: 0.8124
#
# 267/329 [=======================>......]
#  - ETA: 1s - loss: 0.5920 - accuracy: 0.8135
#
# 270/329 [=======================>......]
#  - ETA: 1s - loss: 0.5897 - accuracy: 0.8144
#
# 273/329 [=======================>......]
#  - ETA: 1s - loss: 0.5876 - accuracy: 0.8154
#
# 276/329 [========================>.....]
#  - ETA: 1s - loss: 0.5845 - accuracy: 0.8165
#
# 279/329 [========================>.....]
#  - ETA: 1s - loss: 0.5806 - accuracy: 0.8179
#
# 281/329 [========================>.....]
#  - ETA: 1s - loss: 0.5786 - accuracy: 0.8187
#
# 284/329 [========================>.....]
#  - ETA: 1s - loss: 0.5757 - accuracy: 0.8197
#
# 287/329 [=========================>....]
#  - ETA: 1s - loss: 0.5717 - accuracy: 0.8210
#
# 290/329 [=========================>....]
#  - ETA: 1s - loss: 0.5685 - accuracy: 0.8221
#
# 293/329 [=========================>....]
#  - ETA: 1s - loss: 0.5654 - accuracy: 0.8233
#
# 296/329 [=========================>....]
#  - ETA: 0s - loss: 0.5626 - accuracy: 0.8242
#
# 299/329 [==========================>...]
#  - ETA: 0s - loss: 0.5603 - accuracy: 0.8250
#
# 302/329 [==========================>...]
#  - ETA: 0s - loss: 0.5574 - accuracy: 0.8261
#
# 305/329 [==========================>...]
#  - ETA: 0s - loss: 0.5552 - accuracy: 0.8269
#
# 307/329 [==========================>...]
#  - ETA: 0s - loss: 0.5528 - accuracy: 0.8277
#
# 310/329 [===========================>..]
#  - ETA: 0s - loss: 0.5504 - accuracy: 0.8285
#
# 313/329 [===========================>..]
#  - ETA: 0s - loss: 0.5474 - accuracy: 0.8295
#
# 316/329 [===========================>..]
#  - ETA: 0s - loss: 0.5452 - accuracy: 0.8302
#
# 320/329 [============================>.]
#  - ETA: 0s - loss: 0.5422 - accuracy: 0.8312
#
# 323/329 [============================>.]
#  - ETA: 0s - loss: 0.5401 - accuracy: 0.8320
#
# 326/329 [============================>.]
#  - ETA: 0s - loss: 0.5381 - accuracy: 0.8324
#   0%|                                     | 0/5 [00:11<?, ?trial/s, best loss=?]WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x19012c830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x19012c830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#
# 329/329 [==============================]
#  - 11s 31ms/step - loss: 0.5364 - accuracy: 0.8331 - val_loss: 0.2001 - val_accuracy: 0.9412
#
# Epoch 2/2
#   1/329 [..............................]
#  - ETA: 5s - loss: 0.2791 - accuracy: 0.9062
#
#   5/329 [..............................]
#  - ETA: 4s - loss: 0.2404 - accuracy: 0.9328
#
#   8/329 [..............................]
#  - ETA: 5s - loss: 0.2473 - accuracy: 0.9268
#
#  11/329 [>.............................]
#  - ETA: 5s - loss: 0.2637 - accuracy: 0.9268
#
#  14/329 [>.............................]
#  - ETA: 5s - loss: 0.2647 - accuracy: 0.9280
#
#  17/329 [>.............................]
#  - ETA: 5s - loss: 0.2632 - accuracy: 0.9292
#
#  20/329 [>.............................]
#  - ETA: 5s - loss: 0.2708 - accuracy: 0.9270
#
#  21/329 [>.............................]
#  - ETA: 5s - loss: 0.2721 - accuracy: 0.9271
#
#  24/329 [=>............................]
#  - ETA: 5s - loss: 0.2792 - accuracy: 0.9274
#
#  27/329 [=>............................]
#  - ETA: 5s - loss: 0.2804 - accuracy: 0.9271
#
#  31/329 [=>............................]
#  - ETA: 5s - loss: 0.2773 - accuracy: 0.9284
#
#  34/329 [==>...........................]
#  - ETA: 5s - loss: 0.2756 - accuracy: 0.9288
#
#  37/329 [==>...........................]
#  - ETA: 5s - loss: 0.2708 - accuracy: 0.9299
#
#  39/329 [==>...........................]
#  - ETA: 5s - loss: 0.2660 - accuracy: 0.9311
#
#  42/329 [==>...........................]
#  - ETA: 5s - loss: 0.2666 - accuracy: 0.9302
#
#  45/329 [===>..........................]
#  - ETA: 5s - loss: 0.2616 - accuracy: 0.9309
#
#  48/329 [===>..........................]
#  - ETA: 5s - loss: 0.2596 - accuracy: 0.9307
#
#  51/329 [===>..........................]
#  - ETA: 5s - loss: 0.2555 - accuracy: 0.9312
#
#  55/329 [====>.........................]
#  - ETA: 4s - loss: 0.2519 - accuracy: 0.9314
#
#  59/329 [====>.........................]
#  - ETA: 4s - loss: 0.2489 - accuracy: 0.9323
#
#  62/329 [====>.........................]
#  - ETA: 4s - loss: 0.2513 - accuracy: 0.9317
#
#  64/329 [====>.........................]
#  - ETA: 4s - loss: 0.2517 - accuracy: 0.9315
#
#  67/329 [=====>........................]
#  - ETA: 4s - loss: 0.2531 - accuracy: 0.9314
#
#  70/329 [=====>........................]
#  - ETA: 4s - loss: 0.2562 - accuracy: 0.9310
#
#  73/329 [=====>........................]
#  - ETA: 4s - loss: 0.2530 - accuracy: 0.9315
#
#  76/329 [=====>........................]
#  - ETA: 4s - loss: 0.2533 - accuracy: 0.9314
#
#  79/329 [======>.......................]
#  - ETA: 4s - loss: 0.2529 - accuracy: 0.9315
#
#  82/329 [======>.......................]
#  - ETA: 4s - loss: 0.2550 - accuracy: 0.9309
#
#  85/329 [======>.......................]
#  - ETA: 4s - loss: 0.2568 - accuracy: 0.9303
#
#  89/329 [=======>......................]
#  - ETA: 4s - loss: 0.2566 - accuracy: 0.9300
#
#  92/329 [=======>......................]
#  - ETA: 4s - loss: 0.2552 - accuracy: 0.9303
#
#  95/329 [=======>......................]
#  - ETA: 4s - loss: 0.2538 - accuracy: 0.9305
#
#  98/329 [=======>......................]
#  - ETA: 4s - loss: 0.2537 - accuracy: 0.9303
#
# 101/329 [========>.....................]
#  - ETA: 4s - loss: 0.2517 - accuracy: 0.9307
#
# ...
#
# 221/329 [===================>..........]
#  - ETA: 0s - loss: 0.8836 - accuracy: 0.7016
#
# 229/329 [===================>..........]
#  - ETA: 0s - loss: 0.8696 - accuracy: 0.7069
#
# 237/329 [====================>.........]
#  - ETA: 0s - loss: 0.8546 - accuracy: 0.7124
#
# 245/329 [=====================>........]
#  - ETA: 0s - loss: 0.8415 - accuracy: 0.7176
#
# 253/329 [======================>.......]
#  - ETA: 0s - loss: 0.8293 - accuracy: 0.7229
#
# 261/329 [======================>.......]
#  - ETA: 0s - loss: 0.8164 - accuracy: 0.7280
#
# 269/329 [=======================>......]
#  - ETA: 0s - loss: 0.8061 - accuracy: 0.7320
#
# 277/329 [========================>.....]
#  - ETA: 0s - loss: 0.7955 - accuracy: 0.7361
#
# 285/329 [========================>.....]
#  - ETA: 0s - loss: 0.7845 - accuracy: 0.7400
#
# 293/329 [=========================>....]
#  - ETA: 0s - loss: 0.7741 - accuracy: 0.7437
#
# 301/329 [==========================>...]
#  - ETA: 0s - loss: 0.7646 - accuracy: 0.7472
#
# 309/329 [===========================>..]
#  - ETA: 0s - loss: 0.7548 - accuracy: 0.7505
#
# 317/329 [===========================>..]
#  - ETA: 0s - loss: 0.7448 - accuracy: 0.7543
#
# 325/329 [============================>.]
#  - ETA: 0s - loss: 0.7366 - accuracy: 0.7571
#  80%|████████  | 4/5 [00:56<00:11, 11.84s/trial, best loss: -0.9652000069618225]WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x157fae710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x157fae710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#
# 329/329 [==============================]
#  - 3s 8ms/step - loss: 0.7333 - accuracy: 0.7583 - val_loss: 0.2680 - val_accuracy: 0.9207
#
# Epoch 2/2
#   1/329 [..............................]
#  - ETA: 4s - loss: 0.2216 - accuracy: 0.9375
#
#   9/329 [..............................]
#  - ETA: 2s - loss: 0.3800 - accuracy: 0.8906
#
#  17/329 [>.............................]
#  - ETA: 2s - loss: 0.3697 - accuracy: 0.8920
#
#  24/329 [=>............................]
#  - ETA: 2s - loss: 0.3539 - accuracy: 0.8978
#
#  31/329 [=>............................]
#  - ETA: 2s - loss: 0.3429 - accuracy: 0.9017
#
#  38/329 [==>...........................]
#  - ETA: 2s - loss: 0.3527 - accuracy: 0.8991
#
#  45/329 [===>..........................]
#  - ETA: 2s - loss: 0.3577 - accuracy: 0.8969
#
#  52/329 [===>..........................]
#  - ETA: 1s - loss: 0.3650 - accuracy: 0.8951
#
#  59/329 [====>.........................]
#  - ETA: 1s - loss: 0.3688 - accuracy: 0.8958
#
#  66/329 [=====>........................]
#  - ETA: 1s - loss: 0.3630 - accuracy: 0.8974
#
#  73/329 [=====>........................]
#  - ETA: 1s - loss: 0.3626 - accuracy: 0.8980
#
#  80/329 [======>.......................]
#  - ETA: 1s - loss: 0.3652 - accuracy: 0.8985
#
#  87/329 [======>.......................]
#  - ETA: 1s - loss: 0.3691 - accuracy: 0.8969
#
#  94/329 [=======>......................]
#  - ETA: 1s - loss: 0.3689 - accuracy: 0.8967
#
# 101/329 [========>.....................]
#  - ETA: 1s - loss: 0.3689 - accuracy: 0.8964
#
# 108/329 [========>.....................]
#  - ETA: 1s - loss: 0.3660 - accuracy: 0.8967
#
# 116/329 [=========>....................]
#  - ETA: 1s - loss: 0.3632 - accuracy: 0.8972
#
# 123/329 [==========>...................]
#  - ETA: 1s - loss: 0.3602 - accuracy: 0.8981
#
# 131/329 [==========>...................]
#  - ETA: 1s - loss: 0.3570 - accuracy: 0.8986
#
# 138/329 [===========>..................]
#  - ETA: 1s - loss: 0.3542 - accuracy: 0.8998
#
# 145/329 [============>.................]
#  - ETA: 1s - loss: 0.3519 - accuracy: 0.9001
#
# 152/329 [============>.................]
#  - ETA: 1s - loss: 0.3499 - accuracy: 0.9002
#
# 160/329 [=============>................]
#  - ETA: 1s - loss: 0.3496 - accuracy: 0.9005
#
# 168/329 [==============>...............]
#  - ETA: 1s - loss: 0.3475 - accuracy: 0.9012
#
# 176/329 [===============>..............]
#  - ETA: 1s - loss: 0.3451 - accuracy: 0.9022
#
# 183/329 [===============>..............]
#  - ETA: 1s - loss: 0.3439 - accuracy: 0.9024
#
# 191/329 [================>.............]
#  - ETA: 0s - loss: 0.3434 - accuracy: 0.9028
#
# 198/329 [=================>............]
#  - ETA: 0s - loss: 0.3441 - accuracy: 0.9027
#
# 206/329 [=================>............]
#  - ETA: 0s - loss: 0.3440 - accuracy: 0.9026
#
# 213/329 [==================>...........]
#  - ETA: 0s - loss: 0.3435 - accuracy: 0.9029
#
# 219/329 [==================>...........]
#  - ETA: 0s - loss: 0.3422 - accuracy: 0.9032
#
# 226/329 [===================>..........]
#  - ETA: 0s - loss: 0.3420 - accuracy: 0.9032
#
# 234/329 [====================>.........]
#  - ETA: 0s - loss: 0.3406 - accuracy: 0.9037
#
# 242/329 [=====================>........]
#  - ETA: 0s - loss: 0.3400 - accuracy: 0.9038
#
# 250/329 [=====================>........]
#  - ETA: 0s - loss: 0.3395 - accuracy: 0.9038
#
# 258/329 [======================>.......]
#  - ETA: 0s - loss: 0.3404 - accuracy: 0.9032
#
# 266/329 [=======================>......]
#  - ETA: 0s - loss: 0.3380 - accuracy: 0.9038
#
# 274/329 [=======================>......]
#  - ETA: 0s - loss: 0.3376 - accuracy: 0.9040
#
# 282/329 [========================>.....]
#  - ETA: 0s - loss: 0.3374 - accuracy: 0.9040
#
# 289/329 [=========================>....]
#  - ETA: 0s - loss: 0.3368 - accuracy: 0.9044
#
# 296/329 [=========================>....]
#  - ETA: 0s - loss: 0.3363 - accuracy: 0.9048
#
# 304/329 [==========================>...]
#  - ETA: 0s - loss: 0.3344 - accuracy: 0.9051
#
# 311/329 [===========================>..]
#  - ETA: 0s - loss: 0.3342 - accuracy: 0.9051
#
# 318/329 [===========================>..]
#  - ETA: 0s - loss: 0.3337 - accuracy: 0.9051
#
# 325/329 [============================>.]
#  - ETA: 0s - loss: 0.3324 - accuracy: 0.9056
#
# 329/329 [==============================]
#  - 3s 8ms/step - loss: 0.3323 - accuracy: 0.9057 - val_loss: 0.1986 - val_accuracy: 0.9412
#
# Best validation loss of epoch:
# 0.19858820736408234
# 100%|██████████| 5/5 [01:04<00:00, 12.94s/trial, best loss: -0.9652000069618225]

# %%
best_model = trials.results[np.argmin([r['loss'] for r in trials.results])]['model']
best_model.summary()
# Out:
# Model: "sequential_38"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_222 (Dense)            (None, 500)               392500
# _________________________________________________________________
# dropout_180 (Dropout)        (None, 500)               0
# _________________________________________________________________
# dense_223 (Dense)            (None, 250)               125250
# _________________________________________________________________
# dropout_181 (Dropout)        (None, 250)               0
# _________________________________________________________________
# dense_224 (Dense)            (None, 100)               25100
# _________________________________________________________________
# dropout_182 (Dropout)        (None, 100)               0
# _________________________________________________________________
# dense_225 (Dense)            (None, 100)               10100
# _________________________________________________________________
# dropout_183 (Dropout)        (None, 100)               0
# _________________________________________________________________
# dense_226 (Dense)            (None, 500)               50500
# _________________________________________________________________
# dropout_184 (Dropout)        (None, 500)               0
# _________________________________________________________________
# dense_227 (Dense)            (None, 10)                5010
# =================================================================
# Total params: 608,460
# Trainable params: 608,460
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_images,train_labels, test_images, test_labels = get_data()
pred = np.argmax(best_model.predict(test_images), axis=-1)
label = np.argmax(test_labels, axis = 1)

confusion = confusion_matrix(label, pred)
print(confusion)
# Out:
# [[ 970    0    0    0    1    1    3    1    3    1]
#  [   0 1125    4    0    0    1    1    0    3    1]
#  [  13    2  981    7    7    0    5    7    9    1]
#  [   0    0    4  973    0    6    0    8   10    9]
#  [   2    1    1    0  950    0    6    0    1   21]
#  [   4    0    0   18    1  851    8    0    5    5]
#  [   6    2    0    0    4    8  934    0    4    0]
#  [   3    8    9    1    0    0    0  972    1   34]
#  [   5    2    1    6   14    2    3    3  927   11]
#  [   4    3    1    9   14    2    1    2    4  969]]
